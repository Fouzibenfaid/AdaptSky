# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pickle 
from mpl_toolkits import mplot3d

mpl.rcParams['axes.linewidth'] = 1
plt.rcParams.update({'font.size': 30})
plt.rcParams['figure.figsize'] = (12,12)
plt.rcParams["font.family"] = "Times New Roman"
plt.tick_params(axis='both', which='major', pad=10)
marker_style = dict(color='tab:blue', linestyle='-', linewidth=3, fillstyle='none', clip_on=False)
marker_style_2 = dict(color='tab:orange', linestyle='-', linewidth=3, fillstyle='none', clip_on=False)


Start_Reading_1 = "Pickles/3-USERS-LOS-SumRate-2GHz.pickle"
Start_Reading_2 = "Pickles/3-USERS-LOS-SumRate1-2GHz.pickle"
Start_Reading_3 = "Pickles/3-USERS-LOS-SumRate2-2GHz.pickle"
Start_Reading_4 = "Pickles/3-USERS-LOS-SumRate3-2GHz.pickle"
Start_Reading_5 = "Pickles/3-USERS-LOS-a1-2GHz.pickle"
Start_Reading_6 = "Pickles/3-USERS-LOS-a2-2GHz.pickle"
Start_Reading_7 = "Pickles/3-USERS-LOS-a3-2GHz.pickle"
Start_Reading_8 = "Pickles/SoA-3-USERS-LOS-SumRate-2GHz.pickle"

with open(Start_Reading_1, "rb") as f:
        SUM = pickle.load(f)
        
with open(Start_Reading_2, "rb") as f:
        SUM1 = pickle.load(f)
        
with open(Start_Reading_3, "rb") as f:
        SUM2 = pickle.load(f)
        
with open(Start_Reading_4, "rb") as f:
        SUM3 = pickle.load(f)

with open(Start_Reading_5, "rb") as f:
        a1 = pickle.load(f)
        
with open(Start_Reading_6, "rb") as f:
        a2 = pickle.load(f)
        
with open(Start_Reading_7, "rb") as f:
        a3 = pickle.load(f)
        
with open(Start_Reading_8, "rb") as f:
        SoA_SUM = pickle.load(f)
        
plt.rcParams['figure.figsize'] = (10,10)    
plt.plot(SUM, label="AdaptSky", **marker_style)
plt.plot(SoA_SUM, label="SoA", **marker_style_2)
plt.xlabel('Episode')
plt.ylabel('Transmission Rate (Gbps)')
plt.legend(loc="lower right")
plt.grid()
plt.savefig('AdaptSky-3-USERS-Sum-Rate.pdf', bbox_inches = 'tight')
plt.show()

"""
plt.plot(a1, label="USER1", **marker_style)
plt.plot(a2, label="USER2", **marker_style_2)
plt.plot(a3, label="USER3", **marker_style)
plt.xlabel('Episode')
plt.ylabel('Power allocation (%)')
plt.legend(loc="lower right")
plt.grid()
plt.savefig('AdaptSky-3-USERS-PA.pdf', bbox_inches = 'tight')
plt.show()"""
# Out:
# '\nplt.plot(a1, label="USER1", **marker_style)\nplt.plot(a2, label="USER2", **marker_style_2)\nplt.plot(a3, label="USER3", **marker_style)\nplt.xlabel(\'Episode\')\nplt.ylabel(\'Power allocation (%)\')\nplt.legend(loc="lower right")\nplt.grid()\nplt.savefig(\'AdaptSky-3-USERS-PA.pdf\', bbox_inches = \'tight\')\nplt.show()'
